# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Internship\forage\weatherAUS.csv')
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# Target variable is RainTomorrow

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# null values in all columns except Date and Location

# %%
data.shape
# Out:
# (145460, 23)

# %%
data.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# drop columns that are unnecessary and have too many null values
data = data.drop(['Date','Location','Cloud9am','Cloud3pm','Evaporation','Sunshine'],axis=1)
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6           W           44.0          W
# 1      7.4     25.1       0.0         WNW           44.0        NNW
# 2     12.9     25.7       0.0         WSW           46.0          W
# 3      9.2     28.0       0.0          NE           24.0         SE
# 4     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       1007.7       1007.1     16.9     21.8        No           No
# ...

# %%
# drop rows with null values
data = data.dropna(axis=0)
data.shape
# Out:
# (112925, 17)

# %%
# some columns like WindGustDir, WindDir9am, WindDir3pm, RainToday, RainTomorrow (target) have string data which cannot be used when modelling
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data['WindGustDir'] = le.fit_transform(data['WindGustDir'])
data['WindDir9am'] = le.fit_transform(data['WindDir9am'])
data['WindDir3pm'] = le.fit_transform(data['WindDir3pm'])
data['RainToday'] = le.fit_transform(data['RainToday'])
data['RainTomorrow'] = le.fit_transform(data['RainTomorrow'])

data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#    WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          14          20.0          24.0         71.0         22.0
# 1          15           4.0          22.0         44.0         25.0
# 2          15          19.0          26.0         38.0         30.0
# 3           0          11.0           9.0         45.0         16.0
# 4           7           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# ...

# %%
# create independent and dependent variables
x = data.drop(['RainTomorrow'],axis=1)
y = data['RainTomorrow']

# %%
sns.scatterplot(x = 'MaxTemp', y = 'MinTemp', hue = 'RainTomorrow' , palette = 'inferno',data = data)
# Out:
# <Axes: xlabel='MaxTemp', ylabel='MinTemp'>

# %% [markdown]
# As minimum temperature increases, maximum temperature also increases. It follows a linear relationship.

# %%
sns.scatterplot(x = 'Humidity9am', y = 'Temp9am', hue = 'RainTomorrow' , palette = 'inferno',data = data)
# Out:
# <Axes: xlabel='Humidity9am', ylabel='Temp9am'>

# %% [markdown]
# As humidity increases, the temperature decreases but the chances of rain tomorrow increase. There are more orange dots to the right of the graph.

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %% [markdown]
# The probability of rain tomorrow is highly correlated with Pressure9am, Pressure3pm and Temp3pm. RainToday also affects RainTomorrow

# %%
# split the data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\Nishi Kapadia\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = lr.predict(x_test)
print('confusion matrix')
print(confusion_matrix(y_test, predictions))
print()
print('classification report')
print(classification_report(y_test, predictions))
print()
print('accuracy score')
print(accuracy_score(y_test, predictions))
# Out:
# confusion matrix
# [[25014  1300]
#  [ 3952  3612]]
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90     26314
#            1       0.74      0.48      0.58      7564
#
#     accuracy                           0.84     33878
#    macro avg       0.80      0.71      0.74     33878
# weighted avg       0.83      0.84      0.83     33878
#
#
# accuracy score
# 0.8449731389102072

# %% [markdown]
# #### Has better accuracy than decision tree

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dt.predict(x_test)
print('confusion matrix')
print(confusion_matrix(y_test, predictions))
print()
print('classification report')
print(classification_report(y_test, predictions))
print()
print('accuracy score')
print(accuracy_score(y_test, predictions))
# Out:
# confusion matrix
# [[22456  3858]
#  [ 3514  4050]]
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86     26314
#            1       0.51      0.54      0.52      7564
#
#     accuracy                           0.78     33878
#    macro avg       0.69      0.69      0.69     33878
# weighted avg       0.79      0.78      0.78     33878
#
#
# accuracy score
# 0.7823956549973434

# %% [markdown]
# #### Has the worst accuracy

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = rf.predict(x_test)
print('confusion matrix')
print(confusion_matrix(y_test, predictions))
print()
print('classification report')
print(classification_report(y_test, predictions))
print()
print('accuracy score')
print(accuracy_score(y_test, predictions))
# Out:
# confusion matrix
# [[25088  1226]
#  [ 3697  3867]]
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     26314
#            1       0.76      0.51      0.61      7564
#
#     accuracy                           0.85     33878
#    macro avg       0.82      0.73      0.76     33878
# weighted avg       0.85      0.85      0.84     33878
#
#
# accuracy score
# 0.8546844559891374

# %% [markdown]
# #### Has better accuracy than decision tree and logistic regression. Same accuracy as XGboost

# %% [markdown]
# # XG boost

# %%
import xgboost as xgb

# %%
xgb = xgb.XGBClassifier()
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
pred = xgb.predict(x_test)
print('confusion matrix')
print(confusion_matrix(y_test, predictions))
print()
print('classification report')
print(classification_report(y_test, predictions))
print()
print('accuracy score')
print(accuracy_score(y_test, predictions))
# Out:
# confusion matrix
# [[25088  1226]
#  [ 3697  3867]]
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     26314
#            1       0.76      0.51      0.61      7564
#
#     accuracy                           0.85     33878
#    macro avg       0.82      0.73      0.76     33878
# weighted avg       0.85      0.85      0.84     33878
#
#
# accuracy score
# 0.8546844559891374

# %% [markdown]
# #### Has better accuracy than decision tree and logistic regression. Has the same accuracy as random forest.
